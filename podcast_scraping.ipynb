# %%
import requests
from bs4 import BeautifulSoup
from pydub import AudioSegment
import os
import string
import pandas as pd 
import re
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 500

# %% [markdown]
# ### **Joe Rogan**

# %%
import requests
from xml.etree import ElementTree

def rss_to_dataframe(rss_url):
    response = requests.get(rss_url)
    root = ElementTree.fromstring(response.content)
    channel = root.find('channel')
    items = channel.findall('item')

    data = []
    for item in items:
        title = item.find('title').text
        episode_number = title.split('-')[0].strip('#').strip()
        # Attempt to extract the guest name from the title
        guest_name = ' '.join(title.split('-')[1:]).strip() if '-' in title else 'Unknown'
        download_url = item.find('enclosure').get('url')
        pub_date = item.find('pubDate').text
        # description = item.find('description').text

        data.append({
            'episode_number': episode_number,
            'guest_name': guest_name,
            'title': title,
            'download_url': download_url,
            'publication_date': pub_date,
            # 'description': description
        })

    df = pd.DataFrame(data)
    return df

# %%
rss_url = 'https://feeds.megaphone.fm/GLT1412515089'
df = rss_to_dataframe(rss_url)
df.head(5)
# Out:
#   episode_number        guest_name                     title  \
# 0           2116       Kevin James       #2116 - Kevin James
# 1           2115      Riley Gaines      #2115 - Riley Gaines
# 2           2114       Zack Snyder       #2114 - Zack Snyder
# 3           2113  Christopher Rufo  #2113 - Christopher Rufo
# 4           2112         Dan Soder         #2112 - Dan Soder
#
#                                                         download_url  \
# 0  https://traffic.megaphone.fm/GLT9792092908.mp3?updated=1709916107
# 1  https://traffic.megaphone.fm/GLT2576028300.mp3?updated=1709826288
# 2  https://traffic.megaphone.fm/GLT5800487718.mp3?updated=1709745613
# 3  https://traffic.megaphone.fm/GLT5991726151.mp3?updated=1709675927
# 4  https://traffic.megaphone.fm/GLT4851895679.mp3?updated=1709313869
#
#                   publication_date
# 0  Fri, 08 Mar 2024 18:00:00 -0000
# 1  Thu, 07 Mar 2024 18:00:00 -0000
# 2  Wed, 06 Mar 2024 20:53:00 -0000
# 3  Tue, 05 Mar 2024 18:00:00 -0000
# 4  Fri, 01 Mar 2024 18:00:00 -0000

# %%
df_original = rss_to_dataframe(rss_url)
df_original
# Out:
#      episode_number                          guest_name  \
# 0              2116                         Kevin James
# 1              2115                        Riley Gaines
# 2              2114                         Zack Snyder
# 3              2113                    Christopher Rufo
# 4              2112                           Dan Soder
# ...             ...                                 ...
# 2270              5  John Heffron, Ari Shaffir (Part 1)
# 2271              5  John Heffron, Ari Shaffir (Part 2)
# 2272              3                         Ari Shaffir
# 2273              2                        Brian Redban
# 2274              1                        Brian Redban
#
#                                         title  \
# 0                         #2116 - Kevin James
# 1                        #2115 - Riley Gaines
# 2                         #2114 - Zack Snyder
# 3                    #2113 - Christopher Rufo
# 4                           #2112 - Dan Soder
# ...                                       ...
# 2270  #5 - John Heffron, Ari Shaffir (Part 1)
# 2271  #5 - John Heffron, Ari Shaffir (Part 2)
# 2272                         #3 - Ari Shaffir
# 2273                        #2 - Brian Redban
# 2274                        #1 - Brian Redban
#
#                                                            download_url  \
# 0     https://traffic.megaphone.fm/GLT9792092908.mp3?updated=1709916107
# 1     https://traffic.megaphone.fm/GLT2576028300.mp3?updated=1709826288
# 2     https://traffic.megaphone.fm/GLT5800487718.mp3?updated=1709745613
# 3     https://traffic.megaphone.fm/GLT5991726151.mp3?updated=1709675927
# 4     https://traffic.megaphone.fm/GLT4851895679.mp3?updated=1709313869
# ...                                                                 ...
# 2270  https://traffic.megaphone.fm/GLT6509617473.mp3?updated=1707793295
# 2271  https://traffic.megaphone.fm/GLT1638709117.mp3?updated=1707792863
# 2272  https://traffic.megaphone.fm/GLT3348401207.mp3?updated=1707791361
# 2273  https://traffic.megaphone.fm/GLT3748439860.mp3?updated=1707792837
# 2274  https://traffic.megaphone.fm/GLT2870586379.mp3?updated=1707792696
#
#                      publication_date
# 0     Fri, 08 Mar 2024 18:00:00 -0000
# 1     Thu, 07 Mar 2024 18:00:00 -0000
# 2     Wed, 06 Mar 2024 20:53:00 -0000
# 3     Tue, 05 Mar 2024 18:00:00 -0000
# 4     Fri, 01 Mar 2024 18:00:00 -0000
# ...                               ...
# 2270  Thu, 21 Jan 2010 00:00:00 -0000
# 2271  Thu, 21 Jan 2010 00:00:00 -0000
# 2272  Wed, 06 Jan 2010 00:00:00 -0000
# 2273  Tue, 29 Dec 2009 00:00:00 -0000
# 2274  Thu, 24 Dec 2009 00:00:00 -0000
#
# [2275 rows x 5 columns]

# %%
# Temporary column to check for numeric values
df['is_numeric'] = pd.to_numeric(df['episode_number'], errors='coerce').notna()

df['is_numeric'].value_counts()
# Out:
# is_numeric
# True     2040
# False     235
# Name: count, dtype: int64

# %%
df = df[df['is_numeric'] == True]

df['is_numeric'].value_counts()
# Out:
# is_numeric
# True    2040
# Name: count, dtype: int64

# %%
df.drop('is_numeric', inplace=True, axis = 1)

# %%
df['episode_number'] = df['episode_number'].astype(int)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2040 entries, 0 to 2274
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   episode_number    2040 non-null   int64
#  1   guest_name        2040 non-null   object
#  2   title             2040 non-null   object
#  3   download_url      2040 non-null   object
#  4   publication_date  2040 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 95.6+ KB

# %%
print(df['publication_date'].head())
# Out:
# 0    Fri, 08 Mar 2024 18:00:00 -0000
# 1    Thu, 07 Mar 2024 18:00:00 -0000
# 2    Wed, 06 Mar 2024 20:53:00 -0000
# 3    Tue, 05 Mar 2024 18:00:00 -0000
# 4    Fri, 01 Mar 2024 18:00:00 -0000
# Name: publication_date, dtype: object

# %%
df['publication_date'] = pd.to_datetime(df['publication_date'], format='%a, %d %b %Y %H:%M:%S %z')

# %%
df['episode_number'].value_counts()
# Out:
# episode_number
# 136     5
# 94      4
# 140     4
# 134     3
# 211     2
#        ..
# 1452    1
# 1453    1
# 1454    1
# 1455    1
# 1       1
# Name: count, Length: 2002, dtype: int64

# %%
df.drop('guest_name', inplace=True, axis=1)

# %%
def load_transcripts(df):
    """
    Loads the transcripts from text files specified in a DataFrame column into a list of lists.

    Each sublist in the returned list contains the transcription text of a single podcast episode.
    If a transcription file is missing or the episode does not have an associated transcript,
    an empty string is added instead.

    Parameters:
        df (pd.DataFrame): The DataFrame containing a 'transcription_file' column with paths to the transcription text files.

    Returns:
        list of lists: A list where each element is a list containing the transcription text of an episode.
                    Episodes without a transcription are represented by an empty string in their sublist.

    Example:
        >>> transcript_texts = load_transcripts(df_tal)
        This returns a list of lists where each sublist contains the transcription text of an episode.
    """

    transcripts = []  # This will hold all transcriptions as a list of lists
    for transcript_file in df['transcription_file']:
        if transcript_file != 'No transcript available':
            try:
                with open(transcript_file, 'r', encoding='utf-8') as file:
                    transcription_text = file.read()
            except FileNotFoundError:
                print(f"File not found: {transcript_file}")
                transcription_text = ""  # Handle missing files by adding an empty string
        else:
            transcription_text = ""  # No transcript available for this row
        
        # Append the transcription text as a new list (to keep it as a list of lists)
        transcripts.append([transcription_text])
    return transcripts

# %%
import os

# Define the path to the folder containing the transcriptions
transcriptions_folder = 'JOE'

# Create a new column for the transcriptions, initialize with None or any suitable placeholder

df['transcription_file'] = 'No transcript available'

def find_transcript_file_joe(episode_number):
    """
    Look for a transcript file matching the episode number.
    Returns the filename if found, otherwise returns a placeholder string.
    """
    for filename in os.listdir(transcriptions_folder):
        if filename.startswith(f"#{episode_number} -") and filename.endswith("-transcript.txt"):
            return os.path.join(transcriptions_folder, filename)
    return 'No transcript available'

for index, row in df.iterrows():
    # Get the episode number and find matching transcript file
    transcript_file = find_transcript_file_joe(row['episode_number'])
    
    # Add the file path or name to the DataFrame
    df.at[index, 'transcription_file'] = transcript_file

# %%
df_joe_final = df.loc[df['transcription_file'] != 'No transcript available']
df_joe_final.reset_index(drop=True, inplace=True)

# %%
# df_joe_final.to_csv('joe_rogan_podcast_and_transcripts.csv',index=True)

# %%
# Saving non filtered dataset without transcripts, if they are needed later, remove the .iloc condition
df.reset_index(drop=True, inplace=True)
df.to_csv('joe_rogan_podcast_dataset.csv', index=True)

# %% [markdown]
# ### **JOE ROGAN TRANSCRIPTS LOAD**

# %%
joe_transcript_texts = load_transcripts(df_joe_final)

# %%
len(joe_transcript_texts) == len(df_joe_final)

# %% [markdown]
# ### **Ben Shapiro**

# %%
def rss_to_dataframe_ben(rss_url):
    response = requests.get(rss_url)
    root = ElementTree.fromstring(response.content)
    channel = root.find('channel')
    items = channel.findall('item')

    data = []
    for item in items:
        title = item.find('title').text
        # Use regular expression to extract the episode number more reliably
        episode_number_match = re.search(r'Ep\.?\s*(\d+)', title, re.IGNORECASE)
        episode_number = episode_number_match.group(1) if episode_number_match else 'Unknown'

        # Extract guest name more reliably
        guest_name = title.split('-')[1].strip() if '-' in title else 'Unknown'
        download_url = item.find('enclosure').get('url')
        pub_date = item.find('pubDate').text

        data.append({
            'episode_number': episode_number,
            'guest_name': guest_name,
            'title': title,
            'download_url': download_url,
            'publication_date': pub_date,
        })

    df = pd.DataFrame(data)
    return df

# %%
rss_url_ben = "https://feeds.simplecast.com/C0fPpQ64"
df_ben = rss_to_dataframe_ben(rss_url_ben)
df_ben
# Out:
#      episode_number  \
# 0           Unknown
# 1                10
# 2              1921
# 3           Unknown
# 4              1920
# ...             ...
# 2288              5
# 2289              4
# 2290              3
# 2291              2
# 2292              1
#
#                                                      guest_name  \
# 2292  https://claritaspod.com/measure/arttrk.com/p/24FDE/verifi.podscribe.com/rss/p/pfx.vpixl.com/2jSe3/prfx.byspotify.com/e/dts.podtrac.com/redirect.mp3/mgln.ai/e/121/injector.simplecastaudio.com/01514e65-f508-4e0c-99d9-aad07cea61ff/episodes/6e016f98-bcf7-4d56-9cba-552c8a3837ab/audio/128/default.mp3?aid=rss_feed&awCollectionId=01514e65-f508-4e0c-99d9-aad07cea61ff&awEpisodeId=6e016f98-bcf7-4d56-9cba-552c8a3837ab&feed=C0fPpQ64
#
#                      publication_date
# 0     Sun, 10 Mar 2024 12:00:00 +0000
# 1      Sat, 9 Mar 2024 15:00:00 +0000
# 2      Fri, 8 Mar 2024 16:40:16 +0000
# 3      Fri, 8 Mar 2024 06:02:41 +0000
# 4      Thu, 7 Mar 2024 15:50:04 +0000
# ...                               ...
# 2288   Wed, 7 Oct 2015 15:00:00 +0000
# 2289   Thu, 1 Oct 2015 15:00:00 +0000
# 2290  Wed, 30 Sep 2015 15:00:00 +0000
# 2291  Tue, 22 Sep 2015 15:00:00 +0000
# 2292  Mon, 21 Sep 2015 07:00:00 +0000
#
# [2293 rows x 5 columns]

# %%
df_ben['publication_date'] = pd.to_datetime(df_ben['publication_date'], format='%a, %d %b %Y %H:%M:%S %z')

# %%
df_ben['episode_number'].value_counts()
# Out:
# episode_number
# Unknown    223
# 10           3
# 7            3
# 2            3
# 6            3
#           ...
# 1306         1
# 1307         1
# 1308         1
# 1309         1
# 86           1
# Name: count, Length: 1920, dtype: int64

# %%
df_ben['episode_number'] = pd.to_numeric(df_ben['episode_number'], errors='coerce')

# %%
# Drop rows where episode_number is NaN (i.e., where conversion failed)
df_ben.dropna(subset=['episode_number'], inplace=True)

# %%
df_ben = df_ben.loc[df_ben['guest_name'] != 'Unknown']

# %%
df_ben['episode_number'] = df_ben['episode_number'].astype(int)

df_ben.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1920 entries, 2 to 2292
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   episode_number    1920 non-null   int64
#  1   guest_name        1920 non-null   object
#  2   title             1920 non-null   object
#  3   download_url      1920 non-null   object
#  4   publication_date  1920 non-null   datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), int64(1), object(3)
# memory usage: 90.0+ KB
# /var/folders/jb/rytm79zx10zcs2wb4zr2ptxr0000gn/T/ipykernel_3461/348658514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ben['episode_number'] = df_ben['episode_number'].astype(int)

# %%
df_ben.drop('guest_name', inplace=True, axis=1)
# Out:
# /var/folders/jb/rytm79zx10zcs2wb4zr2ptxr0000gn/T/ipykernel_3461/4195085331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ben.drop('guest_name', inplace=True, axis=1)

# %%
df_ben
# Out:
#       episode_number  \
# 2               1921
# 4               1920
# 5               1919
# 6               1918
# 7               1917
# ...              ...
# 2288               5
# 2289               4
# 2290               3
# 2291               2
# 2292               1
#
#                                                                                       title  \
# 2                                    Ep. 1921 - STATE OF THE UNION: Old Man Screams At Moon
# 4                      Ep. 1920 - IT’S OFFICIALLY ON: Trump vs. Biden II, Electric Boogaloo
# 5                                                             Ep. 1919 - Nikki Haley Is OUT
# 6                                   Ep. 1918 - Peeing in Your Own Eyes To Stop Donald Trump
# 7                          Ep. 1917 - UNANIMOUS Supreme Court Puts Trump Back On The Ballot
# ...                                                                                     ...
# 2288                                                              Ep. 5 - Rubios PC Problem
# 2289                                                                Ep. 4 - Russia in Syria
# 2290                                                         Ep. 3 - Cruz in the Crosshairs
# 2291                                                            Ep. 2 - Shout Your Abortion
# 2292  Ep. 1 - The Obama Administration Excuses Child-Rape in Afghanistan as 'Their Culture'
#
#                                                                                                                                                                                                                                                                                                                                                                                                                
# 2289 2015-10-01 15:00:00+00:00
# 2290 2015-09-30 15:00:00+00:00
# 2291 2015-09-22 15:00:00+00:00
# 2292 2015-09-21 07:00:00+00:00
#
# [1920 rows x 4 columns]

# %%
import os

# Define the path to the folder containing the transcriptions
transcriptions_folder = 'BEN'

# Create a new column for the transcriptions, initialize with None or any suitable placeholder

df_ben['transcription_file'] = 'No transcript available'

def find_transcript_file_ben(episode_number):
    """
    Look for a transcript file matching the episode number.
    Returns the filename if found, otherwise returns a placeholder string.
    """
    for filename in os.listdir(transcriptions_folder):
        if filename.startswith(f"Ep. {episode_number} -") and filename.endswith("-transcript.txt"):
            return os.path.join(transcriptions_folder, filename)
    return 'No transcript available'

for index, row in df_ben.iterrows():
    # Get the episode number and find matching transcript file
    transcript_file = find_transcript_file_ben(row['episode_number'])
    
    # Add the file path or name to the DataFrame
    df_ben.at[index, 'transcription_file'] = transcript_file
# Out:
# /var/folders/jb/rytm79zx10zcs2wb4zr2ptxr0000gn/T/ipykernel_3461/2583412355.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ben['transcription_file'] = 'No transcript available'

# %%
df_ben_final = df_ben.loc[df_ben['transcription_file'] != 'No transcript available']
df_ben_final.reset_index(drop=True, inplace=True)

# %%
# Saving non filtered dataset without transcripts, if they are needed later, remove the .iloc condition
df_ben.reset_index(drop=True, inplace=True)
df_ben.to_csv('ben_shapiro_podcast_dataset.csv', index=True)

# %% [markdown]
# ### **BEN SHAPIRO TRANSCRIPTS LOAD**

# %%
ben_transcript_texts = load_transcripts(df_ben_final)

# %%
len(ben_transcript_texts) == len(df_ben_final)

# %% [markdown]
# # **This American Life**

# %%
from lxml import etree as ET

def rss_to_dataframe_american_life_from_file(filename):
    with open(filename, 'rb') as file:  # Open as binary due to lxml's handling
        content = file.read()
    root = ET.fromstring(content)
    channel = root.find('channel')
    items = channel.findall('item')

    data = []
    episode_count = 0

    for item in items:
        if episode_count >= 1000:
            break

        title = item.find('title').text
        episode_number_match = re.match(r'(\d+):', title)
        episode_number = episode_number_match.group(1) if episode_number_match else 'Unknown'
        
        description = item.find('description').text
        download_url = item.find('enclosure').get('url')
        pub_date = item.find('pubDate').text

        data.append({
            'episode_number': episode_number,
            'title': title,
            # 'description': description,
            'download_url': download_url,
            'publication_date': pub_date,
        })

        episode_count += 1

    df = pd.DataFrame(data)
    return df

# %%
rss_url_american_life = "TALArchive.xml"
df_american_life = rss_to_dataframe_american_life_from_file(rss_url_american_life)
df_american_life
# Out:
#     episode_number                     title  \
# 0              825               825: Yousef
# 1              824       824: Family Meeting
# 2              823    823: The Question Trap
# 3              822  822: The Words to Say It
# 4              821     821: Embrace the Suck
# ..             ...                       ...
# 819              5  5: Anger and Forgiveness
# 820              4              4: Vacations
# 821              3      3: Poultry Slam 1995
# 822              2        2: Small Scale Sin
# 823              1         1: New Beginnings
#
#                                                                                                                                                                                                                    download_url  \
# 0    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/4ffd11f6-dc7b-4682-8080-378f24f41c59/audio/128/default.mp3
# 1    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/65312b31-dc48-4dde-adb2-269d8f7da365/audio/128/default.mp3
# 2    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/5e22d88d-a289-4135-801a-57e6941a1ea3/audio/128/default.mp3
# 3    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/71a53135-f935-412a-b5bf-a07289de0f30/audio/128/default.mp3
# 4    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/938413db-5e79-44e4-9bd0-cba28b1eee22/audio/128/default.mp3
# ..                                                                                                                                                                                                                          ...
# 819                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/5/G6vW91kUb18b0Vm6ep5eO8ekl8JT3gPF4SYIDbYAWKo/5.mp3
# 820                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/4/S4MTKexcwCBxC_OBqs33YVQm2pf85vKt5vmxhsW8hWg/4.mp3
# 821                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/3/3fZqXh-aDaWx6N3Dg2DkXhAhu5SyUIpxcB16R_Jap90/3.mp3
# 822                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/2/s6iVCvP0p-f1qwIeRvubpMzQ8TR05BnA3AsSm1uXuxs/2.mp3
# 823                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/1/f4vcq5NjNe6sLhpHCrnrYIwy4MDsnHERXNinV2Es-cg/1.mp3
#
#                     publication_date
# 0    Fri, 01 Mar 2024 18:00:00 -0400
# 1    Fri, 23 Feb 2024 18:00:00 -0400
# 2    Fri, 02 Feb 2024 18:00:00 -0400
# 3    Fri, 26 Jan 2024 18:00:00 -0400
# 4    Fri, 19 Jan 2024 18:00:00 -0400
# ..                               ...
# 819  Fri, 15 Dec 1995 18:00:00 -0400
# 820  Fri, 08 Dec 1995 18:00:00 -0400
# 821  Fri, 01 Dec 1995 18:00:00 -0400
# 822  Fri, 24 Nov 1995 18:00:00 -0400
# 823  Fri, 17 Nov 1995 18:00:00 -0400
#
# [824 rows x 4 columns]

# %%
df_american_life['episode_number'] = df_american_life['episode_number'].astype(int)
df_american_life['publication_date'] = pd.to_datetime(df_american_life['publication_date'], format='%a, %d %b %Y %H:%M:%S %z')

# %%
df_american_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   episode_number    824 non-null    int64
#  1   title             824 non-null    object
#  2   download_url      824 non-null    object
#  3   publication_date  824 non-null    datetime64[ns, UTC-04:00]
# dtypes: datetime64[ns, UTC-04:00](1), int64(1), object(2)
# memory usage: 25.9+ KB

# %%
df_american_life
# Out:
#      episode_number                     title  \
# 0               825               825: Yousef
# 1               824       824: Family Meeting
# 2               823    823: The Question Trap
# 3               822  822: The Words to Say It
# 4               821     821: Embrace the Suck
# ..              ...                       ...
# 819               5  5: Anger and Forgiveness
# 820               4              4: Vacations
# 821               3      3: Poultry Slam 1995
# 822               2        2: Small Scale Sin
# 823               1         1: New Beginnings
#
#                                                                                                                                                                                                                    download_url  \
# 0    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/4ffd11f6-dc7b-4682-8080-378f24f41c59/audio/128/default.mp3
# 1    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/65312b31-dc48-4dde-adb2-269d8f7da365/audio/128/default.mp3
# 2    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/5e22d88d-a289-4135-801a-57e6941a1ea3/audio/128/default.mp3
# 3    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/71a53135-f935-412a-b5bf-a07289de0f30/audio/128/default.mp3
# 4    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/938413db-5e79-44e4-9bd0-cba28b1eee22/audio/128/default.mp3
# ..                                                                                                                                                                                                                          ...
# 819                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/5/G6vW91kUb18b0Vm6ep5eO8ekl8JT3gPF4SYIDbYAWKo/5.mp3
# 820                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/4/S4MTKexcwCBxC_OBqs33YVQm2pf85vKt5vmxhsW8hWg/4.mp3
# 821                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/3/3fZqXh-aDaWx6N3Dg2DkXhAhu5SyUIpxcB16R_Jap90/3.mp3
# 822                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/2/s6iVCvP0p-f1qwIeRvubpMzQ8TR05BnA3AsSm1uXuxs/2.mp3
# 823                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/1/f4vcq5NjNe6sLhpHCrnrYIwy4MDsnHERXNinV2Es-cg/1.mp3
#
#              publication_date
# 0   2024-03-01 18:00:00-04:00
# 1   2024-02-23 18:00:00-04:00
# 2   2024-02-02 18:00:00-04:00
# 3   2024-01-26 18:00:00-04:00
# 4   2024-01-19 18:00:00-04:00
# ..                        ...
# 819 1995-12-15 18:00:00-04:00
# 820 1995-12-08 18:00:00-04:00
# 821 1995-12-01 18:00:00-04:00
# 822 1995-11-24 18:00:00-04:00
# 823 1995-11-17 18:00:00-04:00
#
# [824 rows x 4 columns]

# %%
df_american_life['episode_number'].value_counts()
# Out:
# episode_number
# 825    1
# 271    1
# 281    1
# 280    1
# 279    1
#       ..
# 548    1
# 547    1
# 546    1
# 545    1
# 1      1
# Name: count, Length: 824, dtype: int64

# %%
df_american_life.head(500)
# Out:
#      episode_number  \
# 0               825
# 1               824
# 2               823
# 3               822
# 4               821
# 5               820
# 6               819
# 7               818
# 8               817
# 9               816
# 10              815
# 11              814
# 12              813
# 13              812
# 14              811
# 15              810
# 16              809
# 17              808
# 18              807
# 19              806
# 20              805
# 21              804
# 22              803
# 23              802
# 24              801
# 25              800
# 26              799
# 27              798
# 28              797
# 29              796
# 30              795
# 31              794
# 32              793
# 33              792
# 34              791
# 476 2008-02-08 18:00:00-04:00
# 477 2008-01-18 18:00:00-04:00
# 478 2007-12-21 18:00:00-04:00
# 479 2007-12-14 18:00:00-04:00
# 480 2007-11-30 18:00:00-04:00
# 481 2007-11-23 18:00:00-04:00
# 482 2007-11-02 18:00:00-04:00
# 483 2007-10-05 18:00:00-04:00
# 484 2007-09-07 18:00:00-04:00
# 485 2007-08-24 18:00:00-04:00
# 486 2007-08-10 18:00:00-04:00
# 487 2007-07-27 18:00:00-04:00
# 488 2007-07-06 18:00:00-04:00
# 489 2007-06-15 18:00:00-04:00
# 490 2007-06-01 18:00:00-04:00
# 491 2007-05-25 18:00:00-04:00
# 492 2007-05-04 18:00:00-04:00
# 493 2007-04-27 18:00:00-04:00
# 494 2007-04-13 18:00:00-04:00
# 495 2007-04-06 18:00:00-04:00
# 496 2007-03-16 18:00:00-04:00
# 497 2007-03-09 18:00:00-04:00
# 498 2007-02-16 18:00:00-04:00
# 499 2007-02-02 18:00:00-04:00

# %%
df_american_life.sort_values(by='episode_number', ascending=False, inplace=True)

# %%
print(df_american_life['title'].head(10))
# Out:
# 0                                                825: Yousef
# 1                                        824: Family Meeting
# 2                                     823: The Question Trap
# 3                                   822: The Words to Say It
# 4                                      821: Embrace the Suck
# 5    820: It Wouldn’t Be Make-Believe If You’d Believe In Me
# 6                 819: Special Bonus Podcast — Yousef’s Week
# 7                      818: Stand Clear of the Closing Doors
# 8                             817: The Cavalry Is Not Coming
# 9                                          816: Poultry Slam
# Name: title, dtype: object

# %%
df_tal = df_american_life

# %% [markdown]
# ### **Filtering to retain only rows which have transcripts**

# %%
import os

# Define the path to the folder containing the transcriptions
transcriptions_folder = 'THIS_AMERICAN_LIFE'

# Create a new column for the transcriptions, initialize with None or any suitable placeholder
df_tal['transcription'] = None

df_tal['transcription_file'] = 'No transcript available'

def find_transcript_file_tal(episode_number):
    """
    Look for a transcript file matching the episode number.
    Returns the filename if found, otherwise returns a placeholder string.
    """
    for filename in os.listdir(transcriptions_folder):
        if filename.startswith(f"{episode_number}_") and filename.endswith("-transcript.txt"):
            return os.path.join(transcriptions_folder, filename)
    return 'No transcript available'

for index, row in df_tal.iterrows():
    # Get the episode number and find matching transcript file
    transcript_file = find_transcript_file_tal(row['episode_number'])
    
    # Add the file path or name to the DataFrame
    df_tal.at[index, 'transcription_file'] = transcript_file

# %%
df_tal.drop('transcription', inplace=True, axis=1)

# %%
df_tal
# Out:
#      episode_number                     title  \
# 0               825               825: Yousef
# 1               824       824: Family Meeting
# 2               823    823: The Question Trap
# 3               822  822: The Words to Say It
# 4               821     821: Embrace the Suck
# ..              ...                       ...
# 819               5  5: Anger and Forgiveness
# 820               4              4: Vacations
# 821               3      3: Poultry Slam 1995
# 822               2        2: Small Scale Sin
# 823               1         1: New Beginnings
#
#                                                                                                                                                                                                                    download_url  \
# 0    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/4ffd11f6-dc7b-4682-8080-378f24f41c59/audio/128/default.mp3
# 1    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/65312b31-dc48-4dde-adb2-269d8f7da365/audio/128/default.mp3
# 2    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/5e22d88d-a289-4135-801a-57e6941a1ea3/audio/128/default.mp3
# 3    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/71a53135-f935-412a-b5bf-a07289de0f30/audio/128/default.mp3
# 4    https://pfx.vpixl.com/6qj4J/dts.podtrac.com/redirect.mp3/chtbl.com/track/8DB4DB/pdst.fm/e/nyt.simplecastaudio.com/bbbcc290-ed3b-44a2-8e5d-5513e38cfe20/episodes/938413db-5e79-44e4-9bd0-cba28b1eee22/audio/128/default.mp3
# ..                                                                                                                                                                                                                          ...
# 819                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/5/G6vW91kUb18b0Vm6ep5eO8ekl8JT3gPF4SYIDbYAWKo/5.mp3
# 820                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/4/S4MTKexcwCBxC_OBqs33YVQm2pf85vKt5vmxhsW8hWg/4.mp3
# 821                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/3/3fZqXh-aDaWx6N3Dg2DkXhAhu5SyUIpxcB16R_Jap90/3.mp3
# 822                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/2/s6iVCvP0p-f1qwIeRvubpMzQ8TR05BnA3AsSm1uXuxs/2.mp3
# 823                                                                                                              https://www.thisamericanlife.org/sites/default/files/audio/1/f4vcq5NjNe6sLhpHCrnrYIwy4MDsnHERXNinV2Es-cg/1.mp3
#
#              publication_date  \
# 0   2024-03-01 18:00:00-04:00
# 1   2024-02-23 18:00:00-04:00
# 2   2024-02-02 18:00:00-04:00
# 3   2024-01-26 18:00:00-04:00
# 4   2024-01-19 18:00:00-04:00
# ..                        ...
# 819 1995-12-15 18:00:00-04:00
# 820 1995-12-08 18:00:00-04:00
# 821 1995-12-01 18:00:00-04:00
# 822 1995-11-24 18:00:00-04:00
# 823 1995-11-17 18:00:00-04:00
#
#                                            transcription_file
# 0               THIS_AMERICAN_LIFE/825_ Yousef-transcript.txt
# 1       THIS_AMERICAN_LIFE/824_ Family Meeting-transcript.txt
# 2    THIS_AMERICAN_LIFE/823_ The Question Trap-transcript.txt
# 3                                     No transcript available
# 4     THIS_AMERICAN_LIFE/821_ Embrace the Suck-transcript.txt
# ..                                                        ...
# 819                                   No transcript available
# 820                                   No transcript available
# 821                                   No transcript available
# 822                                   No transcript available
# 823                                   No transcript available
#
# [824 rows x 5 columns]

# %%
df_tal_final = df_tal[df_tal['transcription_file'] != 'No transcript available']

# %%
df_tal_final.reset_index(drop=True, inplace=True)

# %%
df_tal.to_csv('TAL_podcast_dataset.csv', index=True)

# %%
df_tal_final.to_csv('TAL_podcast_and_transcripts.csv', index=True)

# %% [markdown]
# ### **TAL TRANSCRIPTS LOAD**

# %%
tal_transcript_texts = load_transcripts(df_tal_final)

# %% [markdown]
# ### **Sanity check**

# %%
len(tal_transcript_texts) == len(df_tal_final)

# %% [markdown]
# ### **All Good**

# %%
df_tal.info()

# %% [markdown]
# # **Andrew Huberman**

# %%
def rss_to_dataframe_huberman(rss_url):
    response = requests.get(rss_url)
    root = ElementTree.fromstring(response.content)
    channel = root.find('channel')
    items = channel.findall('item')

    data = []
    for item in items:
        title = item.find('title').text
        # episode number would be assigned auto incremented as there are no specific numbers in this podcast
        download_url = item.find('enclosure').get('url')
        pub_date = item.find('pubDate').text
        # description = item.find('description').text  

        data.append({
            'title': title,
            'download_url': download_url,
            'publication_date': pub_date,
            # 'description': description  # Including description in the DataFrame
        })

    df = pd.DataFrame(data)
    return df

# %%
rss_url_huberman = 'https://feeds.megaphone.fm/hubermanlab'
df_huberman = rss_to_dataframe_huberman(rss_url_huberman)
df_huberman.head(5)

# %%
def auto_indexing(df):
    num_rows = len(df)

    decrementing_sequence = range(num_rows-1, -1, -1)

    df['episode_number'] = list(decrementing_sequence)

    return df

# %%
df_huberman = auto_indexing(df_huberman)

df_huberman = df_huberman[['episode_number', 'title', 'download_url', 'publication_date']]

# %%
df_huberman['episode_number'] = df_huberman['episode_number'].astype(int)

df_huberman['publication_date'] = pd.to_datetime(df_huberman['publication_date'], format='%a, %d %b %Y %H:%M:%S %z')

# %%
df_huberman = df_huberman.sort_values(by='publication_date', ascending=False)

# %%
import os
import difflib

filenames_huberman = [filename for filename in os.listdir(transcriptions_folder) if filename.endswith("-transcript.txt")]

# Define the path to the folder containing the transcriptions
transcriptions_folder = 'HUBERMAN'

# Create a new column for the transcriptions, initialize with None or any suitable placeholder

df_huberman['transcription_file'] = 'No transcript available'

def find_closest_transcript(title, filenames):
    # Normalize the title to improve matching
    title_normalized = title.lower()
    filenames_normalized = [filename.lower().replace("-transcript.txt", "") for filename in filenames]
    
    # Find the closest match
    matches = difflib.get_close_matches(title_normalized, filenames_normalized, n=1, cutoff=0.4)
    
    if matches:
        # If a match is found, return the original filename (with correct casing and suffix)
        match = matches[0]
        for filename in filenames:
            if filename.lower().startswith(match):
                return os.path.join(transcriptions_folder, filename)
    return 'No transcript available'


for index, row in df_huberman.iterrows():
    transcript_file = find_closest_transcript(row['title'], filenames_huberman)
    df_huberman.at[index, 'transcription_file'] = transcript_file

# %%
df_huberman.to_csv('huberman_podcast_and_transcripts.csv', index=True)

# %% [markdown]
# ### **HUBERMAN TRANSCRIPTS LOAD**

# %%
huberman_transcript_texts = load_transcripts(df_huberman)

# %%
len(huberman_transcript_texts) == len(df_huberman)

# %% [markdown]
# # **VOX**

# %%
def rss_to_dataframe_vox(rss_url):
    response = requests.get(rss_url)
    root = ElementTree.fromstring(response.content)
    channel = root.find('channel')
    items = channel.findall('item')

    data = []
    for item in items:
        title = item.find('title').text
        # episode number would be assigned auto incremented as there are no specific numbers in this podcast
        download_url = item.find('enclosure').get('url')
        pub_date = item.find('pubDate').text
        # description = item.find('description').text  

        data.append({
            'title': title,
            'download_url': download_url,
            'publication_date': pub_date,
            # 'description': description  # Including description in the DataFrame
        })

    df = pd.DataFrame(data)
    return df

# %%
rss_url_vox= 'https://feeds.megaphone.fm/VMP5705694065'
df_vox = rss_to_dataframe_vox(rss_url_vox)
df_vox.head(5)
# Out:
#                                      title  \
# 0                    Bringing back the SAT
# 1         Can Reddit survive going public?
# 2                      Why measles is back
# 3  How Israel is upending Democratic races
# 4     Why groceries are still so expensive
#
#                                                                                                                          download_url  \
# 0  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1530889528.mp3?updated=1709921609
# 1  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1976859152.mp3?updated=1709836444
# 2  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP8455187636.mp3?updated=1709753496
# 3  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP7327599366.mp3?updated=1709661154
# 4  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6282330747.mp3?updated=1709586463
#
#                   publication_date
# 0  Fri, 08 Mar 2024 19:00:00 -0000
# 1  Thu, 07 Mar 2024 19:00:00 -0000
# 2  Wed, 06 Mar 2024 19:50:00 -0000
# 3  Tue, 05 Mar 2024 19:00:00 -0000
# 4  Mon, 04 Mar 2024 19:00:00 -0000

# %%
df_vox
# Out:
#                                                   title  \
# 0                                 Bringing back the SAT
# 1                      Can Reddit survive going public?
# 2                                   Why measles is back
# 3               How Israel is upending Democratic races
# 4                  Why groceries are still so expensive
# ...                                                 ...
# 1516                       This Time Could Be Different
# 1517                              Countdown to Day Zero
# 1518                  Breaking the Ice with North Korea
# 1519  Black Panther Is the Most Important Movie of 2018
# 1520                      Six Easy Steps to Nuclear War
#
#                                                                                                                             download_url  \
# 0     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1530889528.mp3?updated=1709921609
# 1     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1976859152.mp3?updated=1709836444
# 2     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP8455187636.mp3?updated=1709753496
# 3     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP7327599366.mp3?updated=1709661154
# 4     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6282330747.mp3?updated=1709586463
# ...                                                                                                                                  ...
# 1516                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6903159456.mp3
# 1517                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP9919331674.mp3
# 1518                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP3675062005.mp3
# 1519                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6640596368.mp3
# 1520  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6556947130.mp3?updated=1642457368
#
#                      publication_date
# 0     Fri, 08 Mar 2024 19:00:00 -0000
# 1     Thu, 07 Mar 2024 19:00:00 -0000
# 2     Wed, 06 Mar 2024 19:50:00 -0000
# 3     Tue, 05 Mar 2024 19:00:00 -0000
# 4     Mon, 04 Mar 2024 19:00:00 -0000
# ...                               ...
# 1516  Fri, 23 Feb 2018 22:16:09 -0000
# 1517  Thu, 22 Feb 2018 20:57:03 -0000
# 1518  Wed, 21 Feb 2018 20:53:17 -0000
# 1519  Tue, 20 Feb 2018 21:31:56 -0000
# 1520  Mon, 19 Feb 2018 20:50:00 -0000
#
# [1521 rows x 3 columns]

# %%
import os
import re

transcriptions_folder = 'VOX'  # Adjust to your actual folder path
df_vox['transcription_file'] = 'No transcript available'

def normalize_string(s):
    """Normalize a string by removing special characters and converting to lowercase."""
    return re.sub(r'[^a-zA-Z0-9\s]', '', s).lower()

def find_normalized_transcript_file(title, folder_path):
    """
    Attempt to find a transcript file with a title matching after normalization.
    Returns the path to the file if found, 'No transcript available' otherwise.
    """
    normalized_title = normalize_string(title)
    for filename in os.listdir(folder_path):
        # Removing the '-transcript.txt' part and normalize
        filename_base = normalize_string(filename.replace('-transcript.txt', ''))
        if normalized_title == filename_base:
            return os.path.join(folder_path, filename)
    return 'No transcript available'

for index, row in df_vox.iterrows():
    transcript_file = find_normalized_transcript_file(row['title'], transcriptions_folder)
    df_vox.at[index, 'transcription_file'] = transcript_file

# %%
df_vox_final = df_vox[df_vox['transcription_file']!= 'No transcript available']

df_vox_final.reset_index(drop=True, inplace=True)

# %%
df_vox_final
# Out:
#      episode_number                                     title  \
# 0              1520                     Bringing back the SAT
# 1              1519          Can Reddit survive going public?
# 2              1518                       Why measles is back
# 3              1517   How Israel is upending Democratic races
# 4              1516      Why groceries are still so expensive
# ..              ...                                       ...
# 846             395                              John Boltin'
# 847             394               Am I gonna die from vaping?
# 848             393                   Gerry with the bad maps
# 849             392      CNN's climate marathon in 20 minutes
# 850             373  Six rivers, three countries, one Kashmir
#
#                                                                                                                            download_url  \
# 0    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1530889528.mp3?updated=1709921609
# 1    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1976859152.mp3?updated=1709836444
# 2    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP8455187636.mp3?updated=1709753496
# 3    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP7327599366.mp3?updated=1709661154
# 4    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6282330747.mp3?updated=1709586463
# ..                                                                                                                                  ...
# 846                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP2608511590.mp3
# 847                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP2063822495.mp3
# 848                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP3456989366.mp3
# 849                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP7839076497.mp3
# 850                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP3525236388.mp3
#
#              publication_date  \
# 0   2024-03-08 19:00:00+00:00
# 1   2024-03-07 19:00:00+00:00
# 2   2024-03-06 19:50:00+00:00
# 3   2024-03-05 19:00:00+00:00
# 4   2024-03-04 19:00:00+00:00
# ..                        ...
# 846 2019-09-10 21:27:24+00:00
# 847 2019-09-09 21:27:50+00:00
# 848 2019-09-06 20:20:26+00:00
# 849 2019-09-05 21:07:57+00:00
# 850 2019-08-08 22:19:37+00:00
#
#                                               transcription_file
# 0                       VOX/Bringing back the SAT-transcript.txt
# 1            VOX/Can Reddit survive going public?-transcript.txt
# 2                         VOX/Why measles is back-transcript.txt
# 3     VOX/How Israel is upending Democratic races-transcript.txt
# 4        VOX/Why groceries are still so expensive-transcript.txt
# ..                                                           ...
# 846                              VOX/John Boltin'-transcript.txt
# 847               VOX/Am I gonna die from vaping?-transcript.txt
# 848                   VOX/Gerry with the bad maps-transcript.txt
# 849      VOX/CNN's climate marathon in 20 minutes-transcript.txt
# 850  VOX/Six rivers, three countries, one Kashmir-transcript.txt
#
# [851 rows x 5 columns]

# %%
df_vox_final = auto_indexing(df_vox_final)
# df_vox = auto_indexing(df_vox)

# df_vox = df_vox[['episode_number', 'title', 'download_url', 'publication_date', 'transcription_file']]
df_vox_final = df_vox_final[['episode_number', 'title', 'download_url', 'publication_date', 'transcription_file']]

df_vox_final['publication_date'] = pd.to_datetime(df_vox_final['publication_date'], format='%a, %d %b %Y %H:%M:%S %z')
# df_vox['publication_date'] = pd.to_datetime(df_vox['publication_date'], format='%a, %d %b %Y %H:%M:%S %z')
# Out:
# /var/folders/jb/rytm79zx10zcs2wb4zr2ptxr0000gn/T/ipykernel_3461/496421227.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['episode_number'] = list(decrementing_sequence)

# %%
df_vox_final
# Out:
#      episode_number                                     title  \
# 0               850                     Bringing back the SAT
# 1               849          Can Reddit survive going public?
# 2               848                       Why measles is back
# 3               847   How Israel is upending Democratic races
# 4               846      Why groceries are still so expensive
# ..              ...                                       ...
# 846               4                              John Boltin'
# 847               3               Am I gonna die from vaping?
# 848               2                   Gerry with the bad maps
# 849               1      CNN's climate marathon in 20 minutes
# 850               0  Six rivers, three countries, one Kashmir
#
#                                                                                                                            download_url  \
# 0    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1530889528.mp3?updated=1709921609
# 1    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP1976859152.mp3?updated=1709836444
# 2    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP8455187636.mp3?updated=1709753496
# 3    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP7327599366.mp3?updated=1709661154
# 4    https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6282330747.mp3?updated=1709586463
# ..                                                                                                                                  ...
# 846                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP2608511590.mp3
# 847                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP2063822495.mp3
# 848                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP3456989366.mp3
# 849                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP7839076497.mp3
# 850                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP3525236388.mp3
#
#              publication_date  \
# 0   2024-03-08 19:00:00+00:00
# 1   2024-03-07 19:00:00+00:00
# 2   2024-03-06 19:50:00+00:00
# 3   2024-03-05 19:00:00+00:00
# 4   2024-03-04 19:00:00+00:00
# ..                        ...
# 846 2019-09-10 21:27:24+00:00
# 847 2019-09-09 21:27:50+00:00
# 848 2019-09-06 20:20:26+00:00
# 849 2019-09-05 21:07:57+00:00
# 850 2019-08-08 22:19:37+00:00
#
#                                               transcription_file
# 0                       VOX/Bringing back the SAT-transcript.txt
# 1            VOX/Can Reddit survive going public?-transcript.txt
# 2                         VOX/Why measles is back-transcript.txt
# 3     VOX/How Israel is upending Democratic races-transcript.txt
# 4        VOX/Why groceries are still so expensive-transcript.txt
# ..                                                           ...
# 846                              VOX/John Boltin'-transcript.txt
# 847               VOX/Am I gonna die from vaping?-transcript.txt
# 848                   VOX/Gerry with the bad maps-transcript.txt
# 849      VOX/CNN's climate marathon in 20 minutes-transcript.txt
# 850  VOX/Six rivers, three countries, one Kashmir-transcript.txt
#
# [851 rows x 5 columns]

# %%
df_vox.to_csv('vox_podcast_dataset.csv', index=True)

df_vox_final.to_csv('vox_podcast_and_transcripts.csv', index=True)

# %% [markdown]
# ### **VOX TRANSCRIPTS LOAD**

# %%
vox_transcript_texts = load_transcripts(df_vox_final)

# %%
len(vox_transcript_texts) == len(df_vox_final)

# %% [markdown]
# # **FINAL DF WITH TRANSCRIPTS --> Will be updated as needed**

# %%
JOE = pd.read_csv('joe_rogan_podcast_and_transcripts.csv')
BEN = pd.read_csv('ben_shapiro_podcast_and_transcripts.csv')
TAL = pd.read_csv('TAL_podcast_and_transcripts.csv')
HUBERMAN = pd.read_csv('huberman_podcast_and_transcripts.csv')
VOX = pd.read_csv('vox_podcast_and_transcripts.csv')

final_df_with_transcripts = pd.concat([JOE, BEN, TAL, HUBERMAN, VOX], ignore_index=True)

# %%
final_df_with_transcripts.drop('Unnamed: 0', inplace=True, axis=1)

# %%
final_df_with_transcripts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   episode_number      1395 non-null   int64
#  1   title               1395 non-null   object
#  2   download_url        1395 non-null   object
#  3   publication_date    1395 non-null   object
#  4   transcription_file  1395 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 54.6+ KB

# %%
final_df_with_transcripts.to_csv('final_df_with_transcripts.csv')

# %% [markdown]
# # **FINAL DF WITHOUT TRANSCRIPTS --> Will be updated as needed**

# %%
JOE_FULL = pd.read_csv('joe_rogan_podcast_dataset.csv')
BEN_FULL = pd.read_csv('ben_shapiro_podcast_dataset.csv')
TAL_FULL = pd.read_csv('TAL_podcast_dataset.csv')
HUBERMAN_FULL = pd.read_csv('huberman_podcast_and_transcripts.csv') # is same with and without transcripts, i.e. all episodes in dataset have transcripts
VOX_FULL = pd.read_csv('vox_podcast_dataset.csv')

final_df_raw = pd.concat([JOE_FULL, BEN_FULL, TAL_FULL, HUBERMAN_FULL, VOX_FULL], ignore_index=True)

# %%
final_df_raw.drop('Unnamed: 0', inplace=True, axis=1)

final_df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6504 entries, 0 to 6503
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   episode_number      6504 non-null   int64
#  1   title               6504 non-null   object
#  2   download_url        6504 non-null   object
#  3   publication_date    6504 non-null   object
#  4   transcription_file  6504 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 254.2+ KB

# %%
final_df_raw
# Out:
#       episode_number                                              title  \
# 0               2116                                #2116 - Kevin James
# 1               2115                               #2115 - Riley Gaines
# 2               2114                                #2114 - Zack Snyder
# 3               2113                           #2113 - Christopher Rufo
# 4               2112                                  #2112 - Dan Soder
# ...              ...                                                ...
# 6499               4                       This Time Could Be Different
# 6500               3                              Countdown to Day Zero
# 6501               2                  Breaking the Ice with North Korea
# 6502               1  Black Panther Is the Most Important Movie of 2018
# 6503               0                      Six Easy Steps to Nuclear War
#
#                                                                                                                             download_url  \
# 0                                                                      https://traffic.megaphone.fm/GLT9792092908.mp3?updated=1709916107
# 1                                                                      https://traffic.megaphone.fm/GLT2576028300.mp3?updated=1709826288
# 2                                                                      https://traffic.megaphone.fm/GLT5800487718.mp3?updated=1709745613
# 3                                                                      https://traffic.megaphone.fm/GLT5991726151.mp3?updated=1709675927
# 4                                                                      https://traffic.megaphone.fm/GLT4851895679.mp3?updated=1709313869
# ...                                                                                                                                  ...
# 6499                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6903159456.mp3
# 6500                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP9919331674.mp3
# 6501                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP3675062005.mp3
# 6502                     https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6640596368.mp3
# 6503  https://www.podtrac.com/pts/redirect.mp3/pdst.fm/e/chtbl.com/track/524GE/traffic.megaphone.fm/VMP6556947130.mp3?updated=1642457368
#
#                publication_date                           transcription_file
# 0     2024-03-08 18:00:00+00:00                      No transcript available
# 1     2024-03-07 18:00:00+00:00                      No transcript available
# 2     2024-03-06 20:53:00+00:00       JOE/#2114 - Zack Snyder-transcript.txt
# 3     2024-03-05 18:00:00+00:00  JOE/#2113 - Christopher Rufo-transcript.txt
# 4     2024-03-01 18:00:00+00:00                      No transcript available
# ...                         ...                                          ...
# 6499  2018-02-23 22:16:09+00:00                      No transcript available
# 6500  2018-02-22 20:57:03+00:00                      No transcript available
# 6501  2018-02-21 20:53:17+00:00                      No transcript available
# 6502  2018-02-20 21:31:56+00:00                      No transcript available
# 6503  2018-02-19 20:50:00+00:00                      No transcript available
#
# [6504 rows x 5 columns]

# %%
final_df_raw.to_csv('final_df_raw.csv')
